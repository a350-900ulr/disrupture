# %%
# %matplotlib inline

from Simulator import Simulator as Sim

sim = Sim(10_000)
sim.disrupt('Meidling')
sim.plot_delay()
# Out:
# Journeys have not been simulated yet, doing now
# Simulating journeys: 100%|██████████| 10000/10000 [01:08<00:00, 146.67it/s]
# Simulating disruption: 100%|██████████| 10000/10000 [00:59<00:00, 166.70it/s]

# %%
# %matplotlib inline

from Simulator import Simulator as Sim

sim = Sim(10_000)
sim.disrupt(['Schwedenplatz', 'Schottenring'])
sim.plot_delay()
# Out:
# Populating transit graph: 100%|██████████| 43/43 [00:00<00:00, 12561.29it/s]
# Journeys have not been simulated yet, doing now
# Simulating journeys: 100%|██████████| 10000/10000 [01:28<00:00, 112.95it/s]
# Simulating segment disruption: 100%|██████████| 10000/10000 [01:30<00:00, 110.42it/s]

# %%
# %matplotlib inline

from Simulator import Simulator as Sim

sim = Sim(10_000)
sim.disrupt(['Parlament', 'Volkstheater', {'1', '2', '71'}])
sim.plot_delay()
# Out:
# Populating transit graph: 100%|██████████| 43/43 [00:00<00:00, 15422.87it/s]
# Journeys have not been simulated yet, doing now
# Simulating journeys: 100%|██████████| 10000/10000 [01:31<00:00, 109.58it/s]
# Simulating segment disruption: 100%|██████████| 10000/10000 [02:09<00:00, 77.14it/s]
